# %% [markdown]
# <center><h1 style="color:#D4AF37"> AEMR Business Analysis </h1>

# %% [markdown]
# <img src = "https://images.squarespace-cdn.com/content/v1/551972d8e4b0d571edc2e2c8/8f3abd33-0916-4415-9b24-593eea1d1e3c/Screen+Shot+2022-04-20+at+12.41.24+PM.png">

# %% [markdown]
# <h1 style="color:#D4AF37"> What's the Business Problem? </h1>
#
# The American Energy Market Regulator (AEMR) is responsible for looking after the
# United States of America’s domestic energy network. The regulator’s responsibility is to
# ensure that America’s energy network remains reliable with minimal disruptions, which
# are known as outages.
#
# There are four key types of outages:
#
# ● Consequential
#
# ● Forced
#
# ● Opportunistic
#
# ● Planned
#
# Recently, the AEMR management team has been increasingly aware of a large number
# of energy providers that submitted outages over the 2016 and 2017 calendar years. The
# management team has expressed a desire to have the following two areas of concern
# addressed:
#
# <b> A) Energy Stability and Market Outages
#     <p>
# B) Energy Losses and Market Reliability </b>`

# %% [markdown]
# **Setup: Load AEMR Database into Environment**

# %%
import requests
from IPython.core.magic import register_line_magic
from IPython.display import HTML
import sqlite3

@register_line_magic
def load_sqlite_db(url):
    response = requests.get(url)

    if response.status_code == 200:
        with open('temp_db_file.db', 'wb') as file:
            file.write(response.content)
        print('SQLite database file downloaded successfully.')
    else:
        print('Failed to download the SQLite database file.')

sqlite_db_url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/AEMR.db'

# %load_sqlite_db $sqlite_db_url

# %load_ext sql

# %sql sqlite:///temp_db_file.db
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# SQLite database file downloaded successfully.

# %% [markdown]
# <h1 style="color:#D4AF37"> Part I. Energy Stability & Market Outages </h1>
#
# **Context:**
# <p>
# Energy stability is a top priority for the AEMR. To maintain energy security and market reliability, it is critical to understand the patterns and severity of outage events. Key questions driving this analysis include:
#
# <p>
# <b>
# <li>  What are the most common types of outages, and how long do they typically last?
# <li>  How frequently do these outages occur?
# <li>  Are certain energy providers consistently more prone to outages, signaling potential systemic reliability risks?
#
# <p>

# %% [markdown]
# # <h3 style="color:#D4AF37"> Business Question One </h3>
# <b> How do outage volumes vary by outage type (Forced, Scheduled, Opportunistic, Consequential) across 2016 and 2017, and what trends or reliability risks emerge over time? </b>

# %%
# %%sql
# SELECT
#     COUNT(*) AS total_number_outages,
#     outage_reason, year
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND year IN (2016, 2017)
# GROUP BY outage_reason, year
# ORDER BY outage_reason, year;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(181, 'Consequential', 2016),
#  (127, 'Consequential', 2017),
#  (1264, 'Forced', 2016),
#  (1622, 'Forced', 2017),
#  (106, 'Opportunistic Maintenance (Planned)', 2016),
#  (102, 'Opportunistic Maintenance (Planned)', 2017),
#  (380, 'Scheduled (Planned)', 2016),
#  (320, 'Scheduled (Planned)', 2017)]

# %% [markdown]
# **Insight:** Between 2016 and 2017, **forced outages rose by 28%**, signaling increased unplanned disruptions and potential reliability concerns. In contrast, scheduled outages fell by 16%, and consequential outages dropped by 30%, suggesting improved containment and planning. Opportunistic maintenance remained stable, reflecting limited proactive flexibility. Overall, forced outages increased, it might suggest declining infrastructure reliability or external factors affecting stability.

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Two </h3>

# %% [markdown]
# <b>What are the monthly trends in approved outage events across 2016 and 2017, and which outage types are increasing over time? </b>

# %%
# %%sql
# select
#     year, month,
#     COUNT(*) AS total_number_outages
# from AEMR_Outage_Table
# where status = 'Approved'
#     AND year in (2016,2017)
# group by year, month
# order by year, month, total_number_outages desc;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2016, 1, 191),
#  (2016, 2, 227),
#  (2016, 3, 136),
#  (2016, 4, 134),
#  (2016, 5, 174),
#  (2016, 6, 168),
#  (2016, 7, 147),
#  (2016, 8, 194),
#  (2016, 9, 124),
#  (2016, 10, 124),
#  (2016, 11, 200),
#  (2016, 12, 112),
#  (2017, 1, 103),
#  (2017, 2, 150),
#  (2017, 3, 109),
#  (2017, 4, 127),
#  (2017, 5, 166),
#  (2017, 6, 204),
#  (2017, 7, 210),
#  (2017, 8, 209),
#  (2017, 9, 172),
#  (2017, 10, 276),
#  (2017, 11, 197),
#  (2017, 12, 248)]

# %% [markdown]
# **Insight:**
# The analysis reveals clear seasonal spikes in outage events, with the second half of the year (July to December) showing consistently higher volumes. This trend may be driven by environmental conditions (e.g., heatwaves or storms) or operational constraints such as delayed maintenance.
#
# While one outage type shows a notable increase in frequency from 2016 to 2017, frequency alone doesn’t fully capture its impact. It’s equally important to consider **outage duration**—as short interruptions may be negligible, but prolonged outages pose a significant threat to energy reliability and supply security.

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Three </h3>

# %% [markdown]
#
#  **Which participants are responsible for the most frequent and prolonged approved outages by type, and what operational risks do they pose?**

# %%
# %%sql
# SELECT
#     Participant_Code,
#     Outage_Reason,
#     Year,
#     COUNT(*) AS total_number_outages,
#     ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))),2) AS avg_outage_duration_days
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
# GROUP BY 1,2,3
# ORDER BY total_number_outages desc;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07),
#  ('GW', 'Forced', 2016, 317, 0.38),
#  ('GW', 'Forced', 2017, 227, 1.06),
#  ('AURICON', 'Forced', 2016, 208, 0.07),
#  ('AUXC', 'Forced', 2016, 206, 0.08),
#  ('MELK', 'Forced', 2017, 177, 2.28),
#  ('TRMOS', 'Forced', 2017, 172, 0.42),
#  ('MELK', 'Forced', 2016, 157, 0.83),
#  ('PUG', 'Forced', 2017, 135, 0.25),
#  ('AUXC', 'Forced', 2017, 120, 0.02),
#  ('MELK', 'Scheduled (Planned)', 2016, 85, 4.61),
#  ('PJRH', 'Forced', 2016, 81, 1.22),
#  ('KORL', 'Forced', 2017, 76, 1.21),
#  ('PJRH', 'Forced', 2017, 72, 0.84),
#  ('MELK', 'Scheduled (Planned)', 2017, 70, 6.89),
#  ('PMC', 'Forced', 2016, 69, 0.49),
#  ('TRMOS', 'Forced', 2016, 65, 0.19),
#  ('KORL', 'Forced', 2016, 53, 0.38),
#  ('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45),
#  ('COLLGAR', 'Forced', 2017, 45, 1.38),
#  ('GW', 'Scheduled (Planned)', 2016, 45, 4.43),
#  ('AURICON', 'Consequential', 2017, 42, 0.21),
#  ('AURICON', 'Consequential', 2016, 41, 0.13),
#  ('PMC', 'Forced', 2017, 40, 0.04),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 39, 0.24),
#  ('PJRH', 'Scheduled (Planned)', 2016, 38, 2.37),
#  ('ENRG', 'Scheduled (Planned)', 2017, 37, 4.96),
#  ('PJRH', 'Scheduled (Planned)', 2017, 35, 2.61),
#  ('TSLA_MGT', 'Consequential', 2016, 30, 0.44),
#  ('COLLGAR', 'Forced', 2016, 29, 1.11),
#  ('ENRG', 'Scheduled (Planned)', 2016, 29, 4.85),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 28, 0.99),
#  ('PMC', 'Scheduled (Planned)', 2016, 27, 1.9),
#  ('GW', 'Scheduled (Planned)', 2017, 26, 2.65),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 24, 0.71),
#  ('PUG', 'Forced', 2016, 24, 0.92),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.18),
#  ('TSLA_MGT', 'Consequential', 2017, 23, 0.34),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 23, 1.97),
#  ('ENRG', 'Forced', 2016, 21, 2.24),
#  ('GW', 'Consequential', 2016, 20, 0.18),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 20, 0.31),
#  ('KORL', 'Scheduled (Planned)', 2016, 20, 6.96),
#  ('MUND', 'Scheduled (Planned)', 2016, 18, 3.53),
#  ('STHRNCRS', 'Forced', 2017, 18, 0.26),
#  ('EUCT', 'Consequential', 2016, 17, 0.41),
#  ('KORL', 'Scheduled (Planned)', 2017, 16, 3.38),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2017, 16, 0.65),
#  ('PUG', 'Scheduled (Planned)', 2016, 16, 1.47),
#  ('ENRG', 'Consequential', 2016, 15, 0.57),
#  ('MUND', 'Forced', 2017, 15, 0.19),
#  ('EUCT', 'Consequential', 2017, 14, 0.32),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 14, 0.22),
#  ('STHRNCRS', 'Scheduled (Planned)', 2017, 14, 0.68),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.28),
#  ('STHRNCRS', 'Forced', 2016, 13, 0.33),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 13, 0.62),
#  ('COLLGAR', 'Consequential', 2016, 12, 0.6),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 4.28),
#  ('DNHR', 'Consequential', 2017, 12, 0.24),
#  ('MCG', 'Forced', 2017, 12, 0.28),
#  ('PMC', 'Scheduled (Planned)', 2017, 12, 1.7),
#  ('DNHR', 'Consequential', 2016, 11, 0.28),
#  ('EUCT', 'Forced', 2016, 11, 5.9),
#  ('PUG', 'Scheduled (Planned)', 2017, 11, 2.25),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.24),
#  ('PMC', 'Consequential', 2016, 10, 0.28),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 9, 6.36),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 9, 0.21),
#  ('STHRNCRS', 'Consequential', 2016, 9, 0.22),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.15),
#  ('PMC', 'Consequential', 2017, 8, 3.52),
#  ('WGUTD', 'Forced', 2017, 8, 3.44),
#  ('ENRG', 'Consequential', 2017, 7, 0.27),
#  ('ENRG', 'Forced', 2017, 7, 0.26),
#  ('MELK', 'Consequential', 2016, 7, 0.76),
#  ('MUND', 'Scheduled (Planned)', 2017, 7, 1.7),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 7, 0.21),
#  ('KORL', 'Consequential', 2017, 6, 2.24),
#  ('WGUTD', 'Consequential', 2016, 6, 1.99),
#  ('COLLGAR', 'Consequential', 2017, 5, 0.23),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.33),
#  ('TRMOS', 'Scheduled (Planned)', 2016, 5, 1.42),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.47),
#  ('GW', 'Consequential', 2017, 4, 0.24),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06),
#  ('MUND', 'Forced', 2016, 4, 0.37),
#  ('TRMOS', 'Scheduled (Planned)', 2017, 4, 2.31),
#  ('TSLA_MGT', 'Forced', 2017, 4, 0.31),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.35),
#  ('EUCT', 'Forced', 2017, 3, 0.03),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.24),
#  ('AUXC', 'Scheduled (Planned)', 2016, 2, 1.25),
#  ('MCG', 'Consequential', 2016, 2, 0.26),
#  ('MCG', 'Consequential', 2017, 2, 0.23),
#  ('STHRNCRS', 'Consequential', 2017, 2, 0.26),
#  ('TSLA_MGT', 'Forced', 2016, 2, 0.25),
#  ('WGUTD', 'Forced', 2016, 2, 0.02),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.05),
#  ('AUXC', 'Consequential', 2016, 1, 0.96),
#  ('AUXC', 'Consequential', 2017, 1, 0.1),
#  ('AUXC', 'Scheduled (Planned)', 2017, 1, 2.88),
#  ('DNHR', 'Forced', 2016, 1, 0.4),
#  ('DNHR', 'Forced', 2017, 1, 0.48),
#  ('MCG', 'Forced', 2016, 1, 0.79),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.08),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25),
#  ('STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.06),
#  ('TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.06),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.6),
#  ('WGUTD', 'Scheduled (Planned)', 2017, 1, 10.58)]

# %% [markdown]
# **Insights: Participant-Level Outage Risk Overview (2016–2017)**
#
# - **AURICON** reported the highest number of forced outages in both 2016 (208) and 2017 (490). Despite the high volume, the average outage duration was just **0.07 days**, indicating frequent but low-severity events. This suggests potential reliability issues tied to recurring minor disruptions or gaps in preventive maintenance.
#
# - **GW** experienced a significant rise in outage duration—from **0.38 days in 2016** to **1.06 days in 2017**—alongside consistently high outage counts. This trend signals deteriorating recovery efficiency and a growing risk to operational continuity.
#
# - **MELK** exhibited the most critical pattern, with both high outage frequency and the **longest durations**: **0.83 days in 2016** and **2.28 days in 2017**. This presents a major reliability concern and highlights the need for urgent infrastructure and process evaluation.
#
# > While AURICON poses a high-frequency but low-impact risk, **GW and MELK represent more severe systemic threats** due to the compounding effect of recurring, prolonged outages. These entities should be prioritized for compliance reviews, root cause investigations, and mitigation planning.

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Four </h3>

# %% [markdown]
# <b> Which participants can be classified as High, Medium, or Low Risk based on their average outage duration, and how can this segmentation inform operational decision-making?

# %% [markdown]
# Risk classification criteria
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day)</li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours</li>
# </b>

# %%
# %%sql
# with avg_duration_days as(
#     SELECT
#     Participant_Code,
#     Outage_Reason,
#     Year,
#     COUNT(*) AS total_number_outages,
#     ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))),2) AS avg_outage_duration_days
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
# GROUP BY Participant_Code,Outage_Reason,Year
# ORDER BY total_number_outages desc)
#
# SELECT *,
# CASE
#     WHEN avg_outage_duration_days > 1 then 'High Risk'
#     WHEN avg_outage_duration_days between 0.5 and 1 then 'Medium Risk'
#     WHEN avg_outage_duration_days between 0 and 0.5 then 'Low Risk'
#     ELSE 'N/A'
#     END as Risk_Classification
# from avg_duration_days
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07, 'Low Risk'),
#  ('GW', 'Forced', 2016, 317, 0.38, 'Low Risk'),
#  ('GW', 'Forced', 2017, 227, 1.06, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 208, 0.07, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 206, 0.08, 'Low Risk'),
#  ('MELK', 'Forced', 2017, 177, 2.28, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 172, 0.42, 'Low Risk'),
#  ('MELK', 'Forced', 2016, 157, 0.83, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 135, 0.25, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 120, 0.02, 'Low Risk'),
#  ('MELK', 'Scheduled (Planned)', 2016, 85, 4.61, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 81, 1.22, 'High Risk'),
#  ('KORL', 'Forced', 2017, 76, 1.21, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 72, 0.84, 'Medium Risk'),
#  ('MELK', 'Scheduled (Planned)', 2017, 70, 6.89, 'High Risk'),
#  ('PMC', 'Forced', 2016, 69, 0.49, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 65, 0.19, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 53, 0.38, 'Low Risk'),
#  ('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89, 'High Risk'),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45, 'High Risk'),
#  ('COLLGAR', 'Forced', 2017, 45, 1.38, 'High Risk'),
#  ('GW', 'Scheduled (Planned)', 2016, 45, 4.43, 'High Risk'),
#  ('AURICON', 'Consequential', 2017, 42, 0.21, 'Low Risk'),
#  ('AURICON', 'Consequential', 2016, 41, 0.13, 'Low Risk'),
#  ('PMC', 'Forced', 2017, 40, 0.04, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 39, 0.24, 'Low Risk'),
#  ('PJRH', 'Scheduled (Planned)', 2016, 38, 2.37, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 37, 4.96, 'High Risk'),
#  ('PJRH', 'Scheduled (Planned)', 2017, 35, 2.61, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 30, 0.44, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 29, 1.11, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 29, 4.85, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 28, 0.99, 'Medium Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 27, 1.9, 'High Risk'),
#  ('GW', 'Scheduled (Planned)', 2017, 26, 2.65, 'High Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 24, 0.71, 'Medium Risk'),
#  ('PUG', 'Forced', 2016, 24, 0.92, 'Medium Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.18, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 23, 0.34, 'Low Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 23, 1.97, 'High Risk'),
#  ('ENRG', 'Forced', 2016, 21, 2.24, 'High Risk'),
#  ('GW', 'Consequential', 2016, 20, 0.18, 'Low Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 20, 0.31, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 20, 6.96, 'High Risk'),
#  ('MUND', 'Scheduled (Planned)', 2016, 18, 3.53, 'High Risk'),
#  ('STHRNCRS', 'Forced', 2017, 18, 0.26, 'Low Risk'),
#  ('EUCT', 'Consequential', 2016, 17, 0.41, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 16, 3.38, 'High Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2017, 16, 0.65, 'Medium Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 16, 1.47, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 15, 0.57, 'Medium Risk'),
#  ('MUND', 'Forced', 2017, 15, 0.19, 'Low Risk'),
#  ('EUCT', 'Consequential', 2017, 14, 0.32, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 14, 0.22, 'Low Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2017, 14, 0.68, 'Medium Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.28, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2016, 13, 0.33, 'Low Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 13, 0.62, 'Medium Risk'),
#  ('COLLGAR', 'Consequential', 2016, 12, 0.6, 'Medium Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 4.28, 'High Risk'),
#  ('DNHR', 'Consequential', 2017, 12, 0.24, 'Low Risk'),
#  ('MCG', 'Forced', 2017, 12, 0.28, 'Low Risk'),
#  ('PMC', 'Scheduled (Planned)', 2017, 12, 1.7, 'High Risk'),
#  ('DNHR', 'Consequential', 2016, 11, 0.28, 'Low Risk'),
#  ('EUCT', 'Forced', 2016, 11, 5.9, 'High Risk'),
#  ('PUG', 'Scheduled (Planned)', 2017, 11, 2.25, 'High Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.24, 'Low Risk'),
#  ('PMC', 'Consequential', 2016, 10, 0.28, 'Low Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 9, 6.36, 'High Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 9, 0.21, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 9, 0.22, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.15, 'Low Risk'),
#  ('PMC', 'Consequential', 2017, 8, 3.52, 'High Risk'),
#  ('WGUTD', 'Forced', 2017, 8, 3.44, 'High Risk'),
#  ('ENRG', 'Consequential', 2017, 7, 0.27, 'Low Risk'),
#  ('ENRG', 'Forced', 2017, 7, 0.26, 'Low Risk'),
#  ('MELK', 'Consequential', 2016, 7, 0.76, 'Medium Risk'),
#  ('MUND', 'Scheduled (Planned)', 2017, 7, 1.7, 'High Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 7, 0.21, 'Low Risk'),
#  ('KORL', 'Consequential', 2017, 6, 2.24, 'High Risk'),
#  ('WGUTD', 'Consequential', 2016, 6, 1.99, 'High Risk'),
#  ('COLLGAR', 'Consequential', 2017, 5, 0.23, 'Low Risk'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.33, 'Low Risk'),
#  ('TRMOS', 'Scheduled (Planned)', 2016, 5, 1.42, 'High Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.47, 'Low Risk'),
#  ('GW', 'Consequential', 2017, 4, 0.24, 'Low Risk'),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06, 'Low Risk'),
#  ('MUND', 'Forced', 2016, 4, 0.37, 'Low Risk'),
#  ('TRMOS', 'Scheduled (Planned)', 2017, 4, 2.31, 'High Risk'),
#  ('TSLA_MGT', 'Forced', 2017, 4, 0.31, 'Low Risk'),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33, 'Low Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.35, 'Low Risk'),
#  ('EUCT', 'Forced', 2017, 3, 0.03, 'Low Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.24, 'Low Risk'),
#  ('AUXC', 'Scheduled (Planned)', 2016, 2, 1.25, 'High Risk'),
#  ('MCG', 'Consequential', 2016, 2, 0.26, 'Low Risk'),
#  ('MCG', 'Consequential', 2017, 2, 0.23, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2017, 2, 0.26, 'Low Risk'),
#  ('TSLA_MGT', 'Forced', 2016, 2, 0.25, 'Low Risk'),
#  ('WGUTD', 'Forced', 2016, 2, 0.02, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.05, 'Low Risk'),
#  ('AUXC', 'Consequential', 2016, 1, 0.96, 'Medium Risk'),
#  ('AUXC', 'Consequential', 2017, 1, 0.1, 'Low Risk'),
#  ('AUXC', 'Scheduled (Planned)', 2017, 1, 2.88, 'High Risk'),
#  ('DNHR', 'Forced', 2016, 1, 0.4, 'Low Risk'),
#  ('DNHR', 'Forced', 2017, 1, 0.48, 'Low Risk'),
#  ('MCG', 'Forced', 2016, 1, 0.79, 'Medium Risk'),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42, 'High Risk'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.08, 'Low Risk'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25, 'Low Risk'),
#  ('STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.06, 'Low Risk'),
#  ('TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.06, 'Low Risk'),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.6, 'Medium Risk'),
#  ('WGUTD', 'Scheduled (Planned)', 2017, 1, 10.58, 'High Risk')]

# %% [markdown]
# **Insights: Risk-Based Participant Classification**
#
# Using average outage duration as the classification criterion, participants were segmented into **High**, **Medium**, and **Low Risk** tiers:
#
# **High Risk Participants**
# These participants experienced **average outages > 1 day (24 hours)** and therefore pose the **greatest risk to operational stability**. Notably:
#
# - **MELK**: Consistently appears across multiple outage types with durations exceeding 2 days (e.g., 2.28 in 2017 and 6.89 for Scheduled).
# - **GW**: While showing a high volume of outages, it also recorded several Scheduled outages with durations of **4.43 days (2016)** and **2.65 days (2017)**.
# - **AURICON**, **COLLGAR**, **KORL**, **PMC**, and **ENRG** also demonstrated prolonged scheduled or forced outages above the 1-day threshold.
#
# These participants require **targeted audits**, **preventive infrastructure improvements**, and **closer compliance monitoring** to reduce downtime.
#
# ---
#
# **Medium Risk Participants**
# With average outage durations between **12 and 24 hours**, these participants are **moderate stability risks**, including:
#
# - **PJRH**, **TSLA_MGT**, **MELK** (in specific years or outage types), **PUG**, and **AUXC**.
# - Although their events are less severe than high-risk participants, these still have potential for compounding operational strain.
#
# They should be **monitored proactively** to prevent escalation and reclassified if durations worsen over time.
#
# ---
#
# **Low Risk Participants**
# These participants maintain **short average outages (< 12 hours)** and are **operationally stable**:
#
# - Includes high-volume entities like **AURICON** (Forced outages averaging 0.07 days) and **AUXC**, **TRMOS**, **DNHR**, among others.
# - These facilities generally present **manageable and predictable outage patterns**, though volume should still be tracked to catch emerging issues.
#
# They can serve as **benchmarks for operational excellence**, but should still adhere to preventive maintenance standards.
#
#
#
# **Conclusion**
#
# Risk-based segmentation provides a **data-driven framework** for prioritizing intervention strategies. By focusing resources on **High Risk participants** with long durations, AEMR can **improve grid resilience**, **reduce energy losses**, and **optimize system-wide reliability**. **Medium Risk participants** should be monitored closely, while **Low Risk participants** can maintain current protocols with periodic review.

# %% [markdown]
# While outage types such as **Consequential**, **Opportunistic**, and **Planned** contribute to overall operational metrics, only **Forced outages** are **unplanned** and pose a direct risk to **grid reliability and energy security**. Including all outage types equally in the risk model may dilute focus from the most critical threats.
#
# To address this, the revised framework focuses solely on **Forced outages**, using a **dual-criteria approach** that incorporates both **average outage duration** and **event frequency** to more accurately assess operational risk.
#
#
# Risk Classification (Forced Outages Only)
#
# - **High Risk**
#   - Average duration > 24 hours  OR
#   - More than 20 outage events
#
# - **Medium Risk**
#   - Average duration between 12–24 hours OR
#   - 10–20 outage events
#
# - **Low Risk**
#   - Average duration < 12 hours OR
#   - Fewer than 10 outage events
#
# This refined model ensures focus remains on **critical unplanned outages**, enabling more effective monitoring, prioritization, and mitigation strategies.

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Five </h3>

# %% [markdown]
# <b> Which participants pose the greatest operational risk based on the frequency and average duration (in days) of their forced outages?

# %%
# %%sql
# with avg_duration_days as(
#     SELECT
#     Participant_Code,
#     Outage_Reason,
#     Year,
#     COUNT(*) AS total_number_outages,
#     ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))),2) AS avg_outage_duration_days
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
# GROUP BY Participant_Code,Outage_Reason,Year
# ORDER BY total_number_outages desc)
#
# SELECT *,
# CASE
#     WHEN avg_outage_duration_days > 1 AND Outage_Reason = 'Forced'
#     OR total_number_outages > 20 then 'High Risk'
#     WHEN avg_outage_duration_days between 0.5 and 1 AND Outage_Reason = 'Forced'
#     OR total_number_outages between 10 and 20 then 'Medium Risk'
#     WHEN avg_outage_duration_days between 0 and 0.5 AND Outage_Reason = 'Forced'
#     OR total_number_outages > 10 then 'Low Risk'
#     ELSE 'N/A'
#     END as Risk_Classification
# from avg_duration_days
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07, 'High Risk'),
#  ('GW', 'Forced', 2016, 317, 0.38, 'High Risk'),
#  ('GW', 'Forced', 2017, 227, 1.06, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 208, 0.07, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 206, 0.08, 'High Risk'),
#  ('MELK', 'Forced', 2017, 177, 2.28, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 172, 0.42, 'High Risk'),
#  ('MELK', 'Forced', 2016, 157, 0.83, 'High Risk'),
#  ('PUG', 'Forced', 2017, 135, 0.25, 'High Risk'),
#  ('AUXC', 'Forced', 2017, 120, 0.02, 'High Risk'),
#  ('MELK', 'Scheduled (Planned)', 2016, 85, 4.61, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 81, 1.22, 'High Risk'),
#  ('KORL', 'Forced', 2017, 76, 1.21, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 72, 0.84, 'High Risk'),
#  ('MELK', 'Scheduled (Planned)', 2017, 70, 6.89, 'High Risk'),
#  ('PMC', 'Forced', 2016, 69, 0.49, 'High Risk'),
#  ('TRMOS', 'Forced', 2016, 65, 0.19, 'High Risk'),
#  ('KORL', 'Forced', 2016, 53, 0.38, 'High Risk'),
#  ('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89, 'High Risk'),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45, 'High Risk'),
#  ('COLLGAR', 'Forced', 2017, 45, 1.38, 'High Risk'),
#  ('GW', 'Scheduled (Planned)', 2016, 45, 4.43, 'High Risk'),
#  ('AURICON', 'Consequential', 2017, 42, 0.21, 'High Risk'),
#  ('AURICON', 'Consequential', 2016, 41, 0.13, 'High Risk'),
#  ('PMC', 'Forced', 2017, 40, 0.04, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 39, 0.24, 'High Risk'),
#  ('PJRH', 'Scheduled (Planned)', 2016, 38, 2.37, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 37, 4.96, 'High Risk'),
#  ('PJRH', 'Scheduled (Planned)', 2017, 35, 2.61, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 30, 0.44, 'High Risk'),
#  ('COLLGAR', 'Forced', 2016, 29, 1.11, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 29, 4.85, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 28, 0.99, 'High Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 27, 1.9, 'High Risk'),
#  ('GW', 'Scheduled (Planned)', 2017, 26, 2.65, 'High Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 24, 0.71, 'High Risk'),
#  ('PUG', 'Forced', 2016, 24, 0.92, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.18, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 23, 0.34, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 23, 1.97, 'High Risk'),
#  ('ENRG', 'Forced', 2016, 21, 2.24, 'High Risk'),
#  ('GW', 'Consequential', 2016, 20, 0.18, 'Medium Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 20, 0.31, 'Medium Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 20, 6.96, 'Medium Risk'),
#  ('MUND', 'Scheduled (Planned)', 2016, 18, 3.53, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2017, 18, 0.26, 'Medium Risk'),
#  ('EUCT', 'Consequential', 2016, 17, 0.41, 'Medium Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 16, 3.38, 'Medium Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2017, 16, 0.65, 'Medium Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 16, 1.47, 'Medium Risk'),
#  ('ENRG', 'Consequential', 2016, 15, 0.57, 'Medium Risk'),
#  ('MUND', 'Forced', 2017, 15, 0.19, 'Medium Risk'),
#  ('EUCT', 'Consequential', 2017, 14, 0.32, 'Medium Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 14, 0.22, 'Medium Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2017, 14, 0.68, 'Medium Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.28, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2016, 13, 0.33, 'Medium Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 13, 0.62, 'Medium Risk'),
#  ('COLLGAR', 'Consequential', 2016, 12, 0.6, 'Medium Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 4.28, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2017, 12, 0.24, 'Medium Risk'),
#  ('MCG', 'Forced', 2017, 12, 0.28, 'Medium Risk'),
#  ('PMC', 'Scheduled (Planned)', 2017, 12, 1.7, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2016, 11, 0.28, 'Medium Risk'),
#  ('EUCT', 'Forced', 2016, 11, 5.9, 'High Risk'),
#  ('PUG', 'Scheduled (Planned)', 2017, 11, 2.25, 'Medium Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.24, 'Medium Risk'),
#  ('PMC', 'Consequential', 2016, 10, 0.28, 'Medium Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 9, 6.36, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 9, 0.21, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2016, 9, 0.22, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.15, 'N/A'),
#  ('PMC', 'Consequential', 2017, 8, 3.52, 'N/A'),
#  ('WGUTD', 'Forced', 2017, 8, 3.44, 'High Risk'),
#  ('ENRG', 'Consequential', 2017, 7, 0.27, 'N/A'),
#  ('ENRG', 'Forced', 2017, 7, 0.26, 'Low Risk'),
#  ('MELK', 'Consequential', 2016, 7, 0.76, 'N/A'),
#  ('MUND', 'Scheduled (Planned)', 2017, 7, 1.7, 'N/A'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 7, 0.21, 'N/A'),
#  ('KORL', 'Consequential', 2017, 6, 2.24, 'N/A'),
#  ('WGUTD', 'Consequential', 2016, 6, 1.99, 'N/A'),
#  ('COLLGAR', 'Consequential', 2017, 5, 0.23, 'N/A'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.33, 'N/A'),
#  ('TRMOS', 'Scheduled (Planned)', 2016, 5, 1.42, 'N/A'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.47, 'N/A'),
#  ('GW', 'Consequential', 2017, 4, 0.24, 'N/A'),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06, 'N/A'),
#  ('MUND', 'Forced', 2016, 4, 0.37, 'Low Risk'),
#  ('TRMOS', 'Scheduled (Planned)', 2017, 4, 2.31, 'N/A'),
#  ('TSLA_MGT', 'Forced', 2017, 4, 0.31, 'Low Risk'),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33, 'N/A'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.35, 'N/A'),
#  ('EUCT', 'Forced', 2017, 3, 0.03, 'Low Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 3, 0.24, 'N/A'),
#  ('AUXC', 'Scheduled (Planned)', 2016, 2, 1.25, 'N/A'),
#  ('MCG', 'Consequential', 2016, 2, 0.26, 'N/A'),
#  ('MCG', 'Consequential', 2017, 2, 0.23, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2017, 2, 0.26, 'N/A'),
#  ('TSLA_MGT', 'Forced', 2016, 2, 0.25, 'Low Risk'),
#  ('WGUTD', 'Forced', 2016, 2, 0.02, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.05, 'N/A'),
#  ('AUXC', 'Consequential', 2016, 1, 0.96, 'N/A'),
#  ('AUXC', 'Consequential', 2017, 1, 0.1, 'N/A'),
#  ('AUXC', 'Scheduled (Planned)', 2017, 1, 2.88, 'N/A'),
#  ('DNHR', 'Forced', 2016, 1, 0.4, 'Low Risk'),
#  ('DNHR', 'Forced', 2017, 1, 0.48, 'Low Risk'),
#  ('MCG', 'Forced', 2016, 1, 0.79, 'Medium Risk'),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42, 'N/A'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.08, 'N/A'),
#  ('PMC', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25, 'N/A'),
#  ('STHRNCRS', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.06, 'N/A'),
#  ('TRMOS', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.06, 'N/A'),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04, 'N/A'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.6, 'N/A'),
#  ('WGUTD', 'Scheduled (Planned)', 2017, 1, 10.58, 'N/A')]

# %% [markdown]
# **Insights:**
#
# - **AURICON, GW, MELK, TRMOS, and PUG** top the **High Risk** list due to frequent **forced outages**, despite many of their individual outages being short in duration.
# This pattern indicates **chronic operational instability** and highlights the need for **preventive maintenance** and **proactive monitoring**.
#
# - **MELK** stands out for exhibiting both **high frequency** and **prolonged outage durations** (e.g., **2.28 days** in 2017), signaling **critical reliability concerns** that may require urgent intervention.
#
# - Participants like **WGUTD** and **ENRG** are currently classified as **Low or Medium Risk** due to fewer or shorter outage durations, but they should still be **monitored over time** to detect any upward trends that may elevate their risk profile.

# %% [markdown]
# <h1 style="color:#D4AF37"> Part II. Energy Losses & Market Reliability </h1>

# %% [markdown]
# ### Objective
#
# As part of a broader initiative to evaluate system resilience, this analysis focuses on **forced outages** to understand their frequency, duration, and overall impact on energy reliability. Given that forced outages are **unplanned supply disruptions**, they present a significant risk to energy security—particularly if multiple providers are affected concurrently.
#
# To support AEMR’s efforts in mitigating these risks, the analysis addresses the following key business questions:
#
# - **What proportion of all outages in 2016 and 2017 were classified as Forced Outages?**
# - **What was the average duration of a forced outage in each of those years, and has the duration increased over time?**
# - **Which energy providers recorded the highest number of forced outages, and do any patterns indicate systemic reliability issues?**
#
#
#
# <img src = "https://media.istockphoto.com/id/1281821795/photo/market-stock-graph-and-information-with-city-light-and-electricity-and-energy-facility-banner.jpg?s=612x612&w=0&k=20&c=RSN5LqeMW28HW10aA190_DWR5YJ5tG2wixHFPBV3uZE=">

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Six </h3>

# %% [markdown]
# <b> What proportion of all approved outages were classified as Forced in 2016 and 2017, and which outage types showed notable increases in frequency over this period? </b>

# %%
# %%sql
# SELECT Year,Total_Outage_Events,Total_Count_Of_Forced_Events,
#     ROUND(1.0 * Total_Count_Of_Forced_Events / Total_Outage_Events *100.00, 2) AS Pct_Outage_Forced
# FROM (
#     SELECT
#         Year, Status,
#         COUNT(*) AS Total_Outage_Events,
#         SUM(CASE WHEN Outage_Reason = 'Forced' THEN 1 ELSE 0 END) AS Total_Count_Of_Forced_Events
#         FROM AEMR_Outage_Table
#         WHERE Status = 'Approved'
#         GROUP BY YEAR) AS sub;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2016, 1931, 1264, 65.46), (2017, 2171, 1622, 74.71)]

# %% [markdown]
# **Insight:**
# Between 2016 and 2017, forced outages increased both in absolute count and as a share of total approved outages, rising from 65.5% to 74.7%. This notable shift highlights a growing operational reliance on reactive recovery rather than proactive maintenance.
#
#
# It’s evident that Forced Outages pose a significant operational and financial risk to the energy grid. Unlike other outage types, forced events are unplanned, meaning energy commitments are broken, leading to immediate energy loss and potential market instability.
#
# Additionally, a subset of energy participants consistently exhibits a disproportionately high number of forced outages, signaling recurring reliability issues.
#
# To drive actionable insights, analysis can be broken down into two layers:
#
# **Macro Analysis** – Measures the total duration of outages per participant to understand overall energy loss impact.
#
# **Micro Analysis** – Examines the average outage duration, revealing whether a few large events are skewing the totals, or whether outages are persistently long throughout the year.
#
# This layered approach helps me to distinguish between participants affected by isolated major incidents vs. those with systemic reliability issues, and ultimately informs regulatory prioritization and preventive intervention strategies.

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Seven </h3>

# %% [markdown]
# **Which participants and facilities contributed most to overall energy loss due to outages, and how can we quantify the operational impact by year?**

# %%
# %%sql
# SELECT
#  COUNT(*) as Total_Number_Outages,
#  ROUND(SUM(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))),2) as Total_Duration_In_Days,
#  ROUND(SUM(Energy_Lost_MW),2) as Total_Energy_Lost, Outage_Reason, Participant_Code, Facility_Code, Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_Reason, Participant_Code, Facility_Code, Year
# ORDER BY Total_Duration_In_Days desc, Year;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(70, 482.58, 7499.28, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2017),
#  (177, 404.15, 10285.4, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (85, 392.25, 9668.79, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2016),
#  (227, 240.69, 19326.56, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (45, 199.4, 6450.0, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (37, 183.58, 516.92, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (29, 140.6, 445.6, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (20, 139.25, 1685.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (157, 129.6, 13771.07, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (317, 120.6, 15751.38, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (81, 98.79, 5881.52, 'Forced', 'PJRH', 'PJRH_GT11', 2016),
#  (76, 91.79, 4679.68, 'Forced', 'KORL', 'KORL_GT3', 2017),
#  (35, 91.35, 2110.01, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (38, 89.9, 2445.0, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (46, 87.02, 6964.8, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (172, 71.9, 5016.67, 'Forced', 'TRMOS', 'TIWEST_COG1', 2017),
#  (26, 68.9, 3812.42, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (45, 65.4, 5941.25, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (11, 64.9, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (18, 63.46, 664.0, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (45, 62.1, 2787.06, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (72, 60.13, 4839.28, 'Forced', 'PJRH', 'PJRH_GT11', 2017),
#  (9, 57.27, 1632.78, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (16, 54.1, 1326.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (27, 51.4, 4839.0, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2016),
#  (12, 51.38, 2139.87, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (21, 47.04, 1182.8, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (23, 45.25, 448.8, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (69, 34.06, 9093.09, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (490, 33.65, 21639.55, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (135, 33.4, 4112.1, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (29, 32.33, 4320.86, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (8, 28.15, 1672.66, 'Consequential', 'PMC', 'PMC_AG', 2017),
#  (28, 27.75, 678.4, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (8, 27.54, 221.29, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (11, 24.73, 1160.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (16, 23.56, 1334.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (24, 22.17, 815.47, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (12, 20.35, 1639.2, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2017),
#  (53, 20.0, 4040.32, 'Forced', 'KORL', 'KORL_GT3', 2016),
#  (24, 17.0, 2877.04, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2016),
#  (206, 16.04, 2734.14, 'Forced', 'AUXC', 'AUXC_WGP', 2016),
#  (208, 15.06, 10696.28, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (6, 13.42, 505.95, 'Consequential', 'KORL', 'KORL_GT3', 2017),
#  (30, 13.21, 297.0, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (65, 12.63, 1232.43, 'Forced', 'TRMOS', 'TIWEST_COG1', 2016),
#  (6, 11.96, 198.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (7, 11.9, 262.46, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (1, 10.58, 36.0, 'Scheduled (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (16, 10.44, 1339.7, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2017),
#  (14, 9.46, 322.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (4, 9.23, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2017),
#  (39, 9.17, 3100.95, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (42, 8.88, 2553.24, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (15, 8.48, 161.4, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (13, 8.04, 299.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (23, 7.73, 227.7, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (12, 7.15, 1374.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (5, 7.08, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (17, 6.96, 290.4, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2016),
#  (20, 6.21, 2951.0, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (7, 5.35, 1524.82, 'Consequential', 'MELK', 'MELK_G7', 2016),
#  (41, 5.31, 3925.55, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (18, 4.65, 292.7, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (14, 4.52, 222.3, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2017),
#  (13, 4.29, 299.0, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (23, 4.21, 2178.95, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (13, 3.67, 1423.53, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (20, 3.6, 832.72, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (12, 3.4, 563.33, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (11, 3.12, 15.84, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (14, 3.04, 1172.05, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (12, 2.9, 17.28, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (1, 2.88, 26.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2017),
#  (15, 2.85, 398.58, 'Forced', 'MUND', 'MUNDARING_GT1', 2017),
#  (10, 2.81, 643.0, 'Consequential', 'PMC', 'PMC_AG', 2016),
#  (2, 2.5, 50.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2016),
#  (10, 2.42, 842.8, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (120, 2.1, 1768.76, 'Forced', 'AUXC', 'AUXC_WGP', 2017),
#  (9, 1.94, 207.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (4, 1.9, 87.0, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (9, 1.9, 335.86, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (7, 1.87, 63.8, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (7, 1.85, 191.86, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (5, 1.65, 763.96, 'Opportunistic Maintenance (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (40, 1.56, 5648.44, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (4, 1.48, 147.2, 'Forced', 'MUND', 'MUNDARING_GT1', 2016),
#  (7, 1.48, 580.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (1, 1.42, 55.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (4, 1.23, 169.9, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (8, 1.21, 248.0, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (5, 1.17, 926.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (3, 1.04, 24.1, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (3, 0.98, 523.0, 'Opportunistic Maintenance (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (1, 0.96, 25.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2016),
#  (4, 0.96, 89.29, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (1, 0.79, 55.0, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (3, 0.71, 348.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (1, 0.6, 36.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (2, 0.52, 110.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (2, 0.52, 46.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (2, 0.5, 160.0, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (1, 0.48, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (2, 0.46, 94.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (1, 0.4, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (1, 0.25, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2017),
#  (4, 0.23, 220.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (1, 0.1, 26.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2017),
#  (3, 0.1, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2017),
#  (2, 0.1, 72.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (1, 0.08, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2016),
#  (1, 0.06, 0.0, 'Opportunistic Maintenance (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (1, 0.06, 23.0, 'Opportunistic Maintenance (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (2, 0.04, 54.0, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (1, 0.04, 36.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017)]

# %% [markdown]
# **Insight:**
#
# An analysis of outage data from **2016–2017** reveals that a **small subset of participants and facilities** account for a **disproportionate share of total energy loss**.
#
# - Specifically, **GW’s `BW1_GREENWATERS_G2`** and **MELK’s `MELK_G7`** facilities consistently top the list due to:
#   - **High outage frequency**, and
#   - **Extended outage durations**, particularly from **forced outages**.
#
# These patterns highlight **systemic reliability issues** at **critical nodes in the grid**, suggesting a need for:
# - **Targeted maintenance investment**
# - **Operational risk reviews**
# - **Proactive resilience planning**

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Eight </h3>

# %% [markdown]
# <b>Which participants and facilities experience the most severe forced outages on average, and how does this vary by year?

# %%
# %%sql
# SELECT
# ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))),2) as Avg_Duration_In_Days,
# ROUND(AVG(Energy_Lost_MW),2) as Avg_Energy_Lost, Outage_Reason, Participant_Code, Facility_Code, Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved' and Outage_Reason = 'Forced'
# GROUP BY Participant_Code, Facility_Code, Year
# ORDER BY Avg_Energy_Lost desc, Year desc;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(1.11, 149.0, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (0.04, 141.21, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (0.49, 131.78, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (0.83, 87.71, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (1.06, 85.14, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (0.25, 80.0, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (0.38, 76.23, 'Forced', 'KORL', 'KORL_GT3', 2016),
#  (1.22, 72.61, 'Forced', 'PJRH', 'PJRH_GT11', 2016),
#  (0.84, 67.21, 'Forced', 'PJRH', 'PJRH_GT11', 2017),
#  (1.38, 61.93, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (1.21, 61.57, 'Forced', 'KORL', 'KORL_GT3', 2017),
#  (2.28, 58.11, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (2.24, 56.32, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (0.79, 55.0, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (0.07, 51.42, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (0.38, 49.69, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (0.28, 46.94, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (0.07, 44.16, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (0.31, 42.48, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (0.37, 36.8, 'Forced', 'MUND', 'MUNDARING_GT1', 2016),
#  (0.92, 33.98, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (0.25, 30.46, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (0.42, 29.17, 'Forced', 'TRMOS', 'TIWEST_COG1', 2017),
#  (3.44, 27.66, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (0.26, 27.41, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (0.02, 27.0, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (0.19, 26.57, 'Forced', 'MUND', 'MUNDARING_GT1', 2017),
#  (0.33, 23.0, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (0.03, 21.6, 'Forced', 'EUCT', 'GRASMERE_WF1', 2017),
#  (0.19, 18.96, 'Forced', 'TRMOS', 'TIWEST_COG1', 2016),
#  (0.26, 16.26, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (0.02, 14.74, 'Forced', 'AUXC', 'AUXC_WGP', 2017),
#  (0.08, 13.27, 'Forced', 'AUXC', 'AUXC_WGP', 2016),
#  (5.9, 5.89, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (0.48, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (0.4, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016)]

# %% [markdown]
# **Insights**:
#
# Analysis of forced outages from 2016–2017 reveals a concentration of severe events among a few key participants and facilities. Notably:
#
# - **COLLGAR**, **PMC**, **MELK**, and **GW** consistently experienced high average energy losses per forced outage, indicating significant operational disruptions.
# - **MELK_G7** and **COLLGAR_WF1** stand out for combining both **long outage durations** (1–2.3 days) and **high energy loss**, reflecting systemic reliability issues.
# - **PMC_AG**, while averaging very **short outage durations** (as low as 0.04 days), still contributed to high energy loss—suggesting high-capacity facilities where even brief outages carry major impact.
# - **WGUTD** recorded the **longest single average outage** (3.44 days in 2017), but with comparatively lower energy lost, pointing to possibly smaller capacity or less critical infrastructure.
# - Some participants such as **EUCT** and **DNHR** had minimal operational impact due to either low energy loss or isolated events.
#
# These findings help prioritize where AEMR should focus reliability improvements—targeting high-loss facilities with frequent or prolonged forced outages.

# %% [markdown]
# # <h3 style="color:#D4AF37"> Business Question Nine </h3>

# %% [markdown]
# <b> Which participants and facilities contributed the most to total energy lost from forced outages during 2016–2017, and what proportion of their total energy loss was due to forced events?

# %%
# %%sql
#
# SELECT
#  ROUND(AVG(Energy_Lost_MW),2) as Avg_Energy_Lost,
#  ROUND(SUM(Energy_Lost_MW),2) as Total_Energy_Lost,
#  ROUND(SUM(Energy_Lost_MW)/(SELECT SUM(Energy_Lost_MW)
#                             FROM AEMR_Outage_Table
#                             WHERE Status = 'Approved' and Outage_Reason = 'Forced')*100.0,2) as Pct_Energy_Loss,
#        Facility_Code, Participant_Code, Outage_Reason, Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved' and Outage_Reason = 'Forced'
# GROUP BY Facility_Code, Participant_Code, Year
# ORDER BY Total_Energy_Lost desc, Year desc;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(44.16, 21639.55, 14.21, 'AURICON_PNJ_U1', 'AURICON', 'Forced', 2017),
#  (85.14, 19326.56, 12.69, 'BW1_GREENWATERS_G2', 'GW', 'Forced', 2017),
#  (49.69, 15751.38, 10.34, 'BW1_GREENWATERS_G2', 'GW', 'Forced', 2016),
#  (87.71, 13771.07, 9.04, 'MELK_G7', 'MELK', 'Forced', 2016),
#  (51.42, 10696.28, 7.02, 'AURICON_PNJ_U1', 'AURICON', 'Forced', 2016),
#  (58.11, 10285.4, 6.75, 'MELK_G7', 'MELK', 'Forced', 2017),
#  (131.78, 9093.09, 5.97, 'PMC_AG', 'PMC', 'Forced', 2016),
#  (72.61, 5881.52, 3.86, 'PJRH_GT11', 'PJRH', 'Forced', 2016),
#  (141.21, 5648.44, 3.71, 'PMC_AG', 'PMC', 'Forced', 2017),
#  (29.17, 5016.67, 3.29, 'TIWEST_COG1', 'TRMOS', 'Forced', 2017),
#  (67.21, 4839.28, 3.18, 'PJRH_GT11', 'PJRH', 'Forced', 2017),
#  (61.57, 4679.68, 3.07, 'KORL_GT3', 'KORL', 'Forced', 2017),
#  (149.0, 4320.86, 2.84, 'COLLGAR_WF1', 'COLLGAR', 'Forced', 2016),
#  (30.46, 4112.1, 2.7, 'PERTHENERGY_KORL_GT1', 'PUG', 'Forced', 2017),
#  (76.23, 4040.32, 2.65, 'KORL_GT3', 'KORL', 'Forced', 2016),
#  (61.93, 2787.06, 1.83, 'COLLGAR_WF1', 'COLLGAR', 'Forced', 2017),
#  (13.27, 2734.14, 1.8, 'AUXC_WGP', 'AUXC', 'Forced', 2016),
#  (14.74, 1768.76, 1.16, 'AUXC_WGP', 'AUXC', 'Forced', 2017),
#  (18.96, 1232.43, 0.81, 'TIWEST_COG1', 'TRMOS', 'Forced', 2016),
#  (56.32, 1182.8, 0.78, 'ENRG_KALGOORLIE_GT3', 'ENRG', 'Forced', 2016),
#  (33.98, 815.47, 0.54, 'PERTHENERGY_KORL_GT1', 'PUG', 'Forced', 2016),
#  (46.94, 563.33, 0.37, 'MWF_MUMBIDA_WF1', 'MCG', 'Forced', 2017),
#  (26.57, 398.58, 0.26, 'MUNDARING_GT1', 'MUND', 'Forced', 2017),
#  (23.0, 299.0, 0.2, 'STHRNCRS_EG', 'STHRNCRS', 'Forced', 2016),
#  (16.26, 292.7, 0.19, 'STHRNCRS_EG', 'STHRNCRS', 'Forced', 2017),
#  (27.66, 221.29, 0.15, 'WEST_KALGOORLIE_GT2', 'WGUTD', 'Forced', 2017),
#  (27.41, 191.86, 0.13, 'ENRG_KALGOORLIE_GT3', 'ENRG', 'Forced', 2017),
#  (42.48, 169.9, 0.11, 'TESLA_PICTON_G1', 'TSLA_MGT', 'Forced', 2017),
#  (80.0, 160.0, 0.11, 'TESLA_PICTON_G1', 'TSLA_MGT', 'Forced', 2016),
#  (36.8, 147.2, 0.1, 'MUNDARING_GT1', 'MUND', 'Forced', 2016),
#  (21.6, 64.8, 0.04, 'GRASMERE_WF1', 'EUCT', 'Forced', 2017),
#  (5.89, 64.8, 0.04, 'GRASMERE_WF1', 'EUCT', 'Forced', 2016),
#  (55.0, 55.0, 0.04, 'MWF_MUMBIDA_WF1', 'MCG', 'Forced', 2016),
#  (27.0, 54.0, 0.04, 'WEST_KALGOORLIE_GT2', 'WGUTD', 'Forced', 2016),
#  (1.44, 1.44, 0.0, 'DNHR_DENMARK_WF1', 'DNHR', 'Forced', 2017),
#  (1.44, 1.44, 0.0, 'DNHR_DENMARK_WF1', 'DNHR', 'Forced', 2016)]

# %% [markdown]
# **Insight:**
# Between 2016 and 2017, forced outages led to significant energy losses, with a small group of participants and facilities contributing a disproportionately high share.
#
# - **AURICON_PNJ_U1 (AURICON)** reported the highest total energy lost from forced outages, with over **21,600 MWh** lost in 2017—accounting for **14.2%** of all forced-outage-related energy loss that year.
#
# - **BW1_GREENWATERS_G2 (GW)** and **MELK_G7 (MELK)** also consistently ranked among the top contributors across both years, indicating **ongoing reliability concerns**.
#
# - **PMC_AG (PMC),** while experiencing shorter outage durations, recorded substantial energy loss due to its **high-capacity generation**, totaling **over 14,700 MWh** lost across 2016 and 2017.
#
# > **Overall**, the top 5 facilities accounted for **more than 50%** of total energy lost from forced outages, underscoring the need for **targeted intervention** at high-impact sites.
#
# These findings offer a clear direction for AEMR to **prioritize reliability investments**, conduct **performance audits**, or pursue **infrastructure upgrades** at the most vulnerable grid nodes.

# %%
# %%sql
#
# SELECT
#   ROUND(AVG(Energy_Lost_MW), 2) AS Avg_Energy_Lost,
#   ROUND(SUM(Energy_Lost_MW), 2) AS Total_Energy_Lost,
#   ROUND(
#     SUM(Energy_Lost_MW) * 100.0 /
#     (SELECT SUM(Energy_Lost_MW)
#      FROM AEMR_Outage_Table
#      WHERE Status = 'Approved'
#        AND Outage_Reason = 'Forced'
#        AND Year = outer_tbl.Year),
#     2
#   ) AS Pct_Energy_Loss,
#   Facility_Code,
#   Participant_Code,
#   Outage_Reason,
#   Year
# FROM AEMR_Outage_Table AS outer_tbl
# WHERE Status = 'Approved'
#   AND Outage_Reason = 'Forced'
# GROUP BY Facility_Code, Participant_Code, Year
# ORDER BY Total_Energy_Lost DESC, Year DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(44.16, 21639.55, 26.39, 'AURICON_PNJ_U1', 'AURICON', 'Forced', 2017),
#  (85.14, 19326.56, 23.57, 'BW1_GREENWATERS_G2', 'GW', 'Forced', 2017),
#  (49.69, 15751.38, 22.41, 'BW1_GREENWATERS_G2', 'GW', 'Forced', 2016),
#  (87.71, 13771.07, 19.59, 'MELK_G7', 'MELK', 'Forced', 2016),
#  (51.42, 10696.28, 15.22, 'AURICON_PNJ_U1', 'AURICON', 'Forced', 2016),
#  (58.11, 10285.4, 12.54, 'MELK_G7', 'MELK', 'Forced', 2017),
#  (131.78, 9093.09, 12.93, 'PMC_AG', 'PMC', 'Forced', 2016),
#  (72.61, 5881.52, 8.37, 'PJRH_GT11', 'PJRH', 'Forced', 2016),
#  (141.21, 5648.44, 6.89, 'PMC_AG', 'PMC', 'Forced', 2017),
#  (29.17, 5016.67, 6.12, 'TIWEST_COG1', 'TRMOS', 'Forced', 2017),
#  (67.21, 4839.28, 5.9, 'PJRH_GT11', 'PJRH', 'Forced', 2017),
#  (61.57, 4679.68, 5.71, 'KORL_GT3', 'KORL', 'Forced', 2017),
#  (149.0, 4320.86, 6.15, 'COLLGAR_WF1', 'COLLGAR', 'Forced', 2016),
#  (30.46, 4112.1, 5.01, 'PERTHENERGY_KORL_GT1', 'PUG', 'Forced', 2017),
#  (76.23, 4040.32, 5.75, 'KORL_GT3', 'KORL', 'Forced', 2016),
#  (61.93, 2787.06, 3.4, 'COLLGAR_WF1', 'COLLGAR', 'Forced', 2017),
#  (13.27, 2734.14, 3.89, 'AUXC_WGP', 'AUXC', 'Forced', 2016),
#  (14.74, 1768.76, 2.16, 'AUXC_WGP', 'AUXC', 'Forced', 2017),
#  (18.96, 1232.43, 1.75, 'TIWEST_COG1', 'TRMOS', 'Forced', 2016),
#  (56.32, 1182.8, 1.68, 'ENRG_KALGOORLIE_GT3', 'ENRG', 'Forced', 2016),
#  (33.98, 815.47, 1.16, 'PERTHENERGY_KORL_GT1', 'PUG', 'Forced', 2016),
#  (46.94, 563.33, 0.69, 'MWF_MUMBIDA_WF1', 'MCG', 'Forced', 2017),
#  (26.57, 398.58, 0.49, 'MUNDARING_GT1', 'MUND', 'Forced', 2017),
#  (23.0, 299.0, 0.43, 'STHRNCRS_EG', 'STHRNCRS', 'Forced', 2016),
#  (16.26, 292.7, 0.36, 'STHRNCRS_EG', 'STHRNCRS', 'Forced', 2017),
#  (27.66, 221.29, 0.27, 'WEST_KALGOORLIE_GT2', 'WGUTD', 'Forced', 2017),
#  (27.41, 191.86, 0.23, 'ENRG_KALGOORLIE_GT3', 'ENRG', 'Forced', 2017),
#  (42.48, 169.9, 0.21, 'TESLA_PICTON_G1', 'TSLA_MGT', 'Forced', 2017),
#  (80.0, 160.0, 0.23, 'TESLA_PICTON_G1', 'TSLA_MGT', 'Forced', 2016),
#  (36.8, 147.2, 0.21, 'MUNDARING_GT1', 'MUND', 'Forced', 2016),
#  (21.6, 64.8, 0.08, 'GRASMERE_WF1', 'EUCT', 'Forced', 2017),
#  (5.89, 64.8, 0.09, 'GRASMERE_WF1', 'EUCT', 'Forced', 2016),
#  (55.0, 55.0, 0.08, 'MWF_MUMBIDA_WF1', 'MCG', 'Forced', 2016),
#  (27.0, 54.0, 0.08, 'WEST_KALGOORLIE_GT2', 'WGUTD', 'Forced', 2016),
#  (1.44, 1.44, 0.0, 'DNHR_DENMARK_WF1', 'DNHR', 'Forced', 2017),
#  (1.44, 1.44, 0.0, 'DNHR_DENMARK_WF1', 'DNHR', 'Forced', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Business Question Ten </h3>

# %% [markdown]
# <b>What are the primary causes behind the highest energy losses for the top three participants (GW, MELK, and AURICON), and how much do these outage reasons contribute to their overall energy loss?

# %%
# %%sql
# SELECT
#   Participant_Code,
#   Facility_Code,
#   Description_Of_Outage,
#   ROUND(SUM(Energy_Lost_MW), 2) AS Total_Energy_Lost,
#   ROUND(SUM(Energy_Lost_MW) * 100.0 /
#         (SELECT SUM(Energy_Lost_MW)
#          FROM AEMR_Outage_Table
#          WHERE Status = 'Approved' AND Outage_Reason = 'Forced'), 2) AS Pct_Energy_Loss,
#   RANK() OVER (PARTITION BY Participant_Code ORDER BY SUM(Energy_Lost_MW) DESC) AS rank
# FROM AEMR_Outage_Table
# WHERE Participant_Code IN ('GW', 'MELK', 'AURICON')
#   AND Status = 'Approved'
#   AND Outage_Reason = 'Forced'
# GROUP BY Participant_Code, Facility_Code, Description_Of_Outage
# ORDER BY Participant_Code, Total_Energy_Lost DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.96, 1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Return to service from outage delayed', 1573.0, 1.03, 2),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit maximum output was restricted to 100 MW as-generated due to high rotor temperature alarm for safety purposes', 1167.73, 0.77, 3),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 vibration issues during start-up sequence.', 1140.0, 0.75, 4),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up.', 676.94, 0.44, 5),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit RTS & ramp-up delayed due to reset of overspeed tripping solenoid.', 564.53, 0.37, 6),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit trip', 530.27, 0.35, 7),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wagerup unit 2 trip, control fault', 499.64, 0.33, 8),
#  ('AURICON', 'AURICON_PNJ_U1', 'Pinjarra Unit 2 ramping up from an outage', 472.19, 0.31, 9),
#  ('AURICON', 'AURICON_PNJ_U1', 'Limited output due to ambient conditions (High temperature)', 460.4, 0.3, 10),
#  ('AURICON', 'AURICON_PNJ_U1', 'Pinjarra Unit 2 tripped due to blade path temperature deviation', 419.99, 0.28, 11),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up', 384.4, 0.25, 12),
#  ('AURICON', 'AURICON_PNJ_U1', 'A-inspection outage extended', 380.0, 0.25, 13),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit trip due to high combustion pulsation', 380.0, 0.25, 13),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP GT delayed ramp-up due to start failure.', 374.25, 0.25, 15),
#  ('AURICON', 'AURICON_PNJ_U1', 'Protective load shed trip', 365.02, 0.24, 16),
#  ('AURICON', 'AURICON_PNJ_U1', 'Operational issues caused real time forced outage.', 362.41, 0.24, 17),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U1 max output reduced due to ambient conditions.', 348.27, 0.23, 18),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP1 gas control valve erratic, unit offline to reset/restart', 312.76, 0.21, 19),
#  ('AURICON', 'AURICON_PNJ_U1', 'Plant failed to reach target due to operational issue.', 309.65, 0.2, 20),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit had problems ramping up and staying to min load', 303.84, 0.2, 21),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ1 max output reduced due to ambient conditions.', 298.51, 0.2, 22),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output limited due to ambient condition.', 296.04, 0.19, 23),
#  ('AURICON', 'AURICON_PNJ_U1', 'Ambient temperature, capacity limit', 293.81, 0.19, 24),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp on start up', 290.37, 0.19, 25),
#  ('AURICON', 'AURICON_PNJ_U1', 'Late ramp up', 287.03, 0.19, 26),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit is unavailable after tripping on return to service.\n', 286.0, 0.19, 27),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Contractor tuning requirement\n', 267.8, 0.18, 28),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation during ramp up from outage', 264.91, 0.17, 29),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 delayed ramp-up due to start failure.', 251.62, 0.17, 30),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U2 start up profile on return to service', 250.8, 0.16, 31),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output reduced due to ambient conditions', 245.32, 0.16, 32),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit tripped due to blown fuse on blade pass temperature element', 242.56, 0.16, 33),
#  ('AURICON', 'AURICON_PNJ_U1', 'Plant pulsation alarm issue', 220.03, 0.14, 34),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up', 190.57, 0.13, 35),
#  ('AURICON', 'AURICON_PNJ_U1', 'Battery charger fault discovered', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Battery charger fault discovered.', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Extension of outage #228336 due to unforeseen workscope overrun', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Routine Maintenance Outage extended - Sequence Release issue', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Routine maintenance outage overrun', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'The unit failed to start.\n', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to meet dispatch instruction', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to meet dispatch instruction\n', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to reach dispatch target issued by Random Number Generator.', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit failed to start.', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 not started due to uneconomic short run.', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 start fail due to fuel drain valve limit switch fault', 190.0, 0.12, 36),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit had problems ramping up to dispatch target', 188.26, 0.12, 48),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not reach target', 184.59, 0.12, 49),
#  ('AURICON', 'AURICON_PNJ_U1', 'delayed synchronization due to failure of fuel drain valve close limit switch', 177.33, 0.12, 50),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delayed synch due to breaker fault', 167.91, 0.11, 51),
#  ('AURICON', 'AURICON_PNJ_U1', 'Flame out trip during loading for capacity test', 163.96, 0.11, 52),
#  ('AURICON', 'AURICON_PNJ_U1', 'Operational issues caused unit trip.', 162.07, 0.11, 53),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wagerup U1 slow to ramp due to plant issues', 159.68, 0.1, 54),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U1 delayed return to service after outage', 158.2, 0.1, 55),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delay in unit ramp-up', 157.88, 0.1, 56),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp to dispatch target following unexpected direction to commit from System Management', 156.01, 0.1, 57),
#  ('AURICON', 'AURICON_PNJ_U1', 'fuel gas control valve issue', 152.86, 0.1, 58),
#  ('AURICON', 'AURICON_PNJ_U1', 'Issues with ramping up\n', 152.25, 0.1, 59),
#  ('AURICON', 'AURICON_PNJ_U1', 'Fuel valves issue', 151.79, 0.1, 60),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not meet target during ramp-up', 148.29, 0.1, 61),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wind farm tripped', 147.1, 0.1, 62),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramp-up', 146.41, 0.1, 63),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U2 delayed return from Blade Wash Outage due to Steam Leak', 143.0, 0.09, 64),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit trip during RTS from blade wash outage', 143.0, 0.09, 64),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit tripped during startup coming from outage due to a HH alarm on IP drum level.', 143.0, 0.09, 64),
#  ('AURICON', 'AURICON_PNJ_U1', 'Late synchronisation due to communications failure between the control room and the unit', 136.43, 0.09, 67),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit slow to ramp up', 136.24, 0.09, 68),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit in commissioning. Ramping issue.', 135.92, 0.09, 69),
#  ('AURICON', 'AURICON_PNJ_U1', 'Late ramp up.', 133.8, 0.09, 70),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 shut down early - Email advice from Trading not received', 133.1, 0.09, 71),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit start-up profile operational requirement', 132.55, 0.09, 72),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up. ', 131.64, 0.09, 73),
#  ('AURICON', 'AURICON_PNJ_U1', 'slow to ramp up', 131.23, 0.09, 74),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit issues ramping up to dispatch target due to safety concern when high rotor temperature alarm got activated', 124.58, 0.08, 75),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit restart, plant conditions preventing unit following ramp up profile', 122.08, 0.08, 76),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up', 120.19, 0.08, 77),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up, unit returning to service from outage\n', 119.28, 0.08, 78),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit tripped while ramping up to full load on return to service.\n', 114.87, 0.08, 79),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up\n', 111.42, 0.07, 80),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Stack emission testing requirement\n', 111.28, 0.07, 81),
#  ('AURICON', 'AURICON_PNJ_U1', 'high LP drum pressure as a result of the failure of the feedback arm from the IP to lp bled steam valve', 110.74, 0.07, 82),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delayed RTS of the unit from blade wash', 109.36, 0.07, 83),
#  ('AURICON', 'AURICON_PNJ_U1', 'Ambient condition limitation', 108.28, 0.07, 84),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not reach target due to unit trip.', 107.77, 0.07, 85),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Contractor tuning requireme', 100.33, 0.07, 86),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not reach target.', 98.26, 0.06, 87),
#  ('AURICON', 'AURICON_PNJ_U1', 'Cold ambient temp, no high fogging permissives', 95.51, 0.06, 88),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit shut down for outage.', 89.14, 0.06, 89),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 1 and 2 offline for HV maintenance', 89.1, 0.06, 90),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up from outage', 88.59, 0.06, 91),
#  ('AURICON', 'AURICON_PNJ_U1', 'Derating due to Ambient condition', 88.26, 0.06, 92),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 1 and Collector groups 1 to 3 offline for HV maintenance', 88.2, 0.06, 93),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramping up following RTS delay due to unit trip', 87.8, 0.06, 94),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delay in unit ramp up', 87.53, 0.06, 95),
#  ('AURICON', 'AURICON_PNJ_U1', 'WWF tripped as runback scheme was invoked due to MBA - TS 81 line tripped. MBA TS 81 line tripped due to storms and lightning strikes in the North Country region. Information based on Dispatch Advisory 16400 and 16401 from Western Power.', 87.45, 0.06, 96),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous dispatch due to power augmentation issues.', 85.95, 0.06, 97),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp down before outage.', 81.82, 0.05, 98),
#  ('AURICON', 'AURICON_PNJ_U1', "Unit's output was constrained due to ventilation fan issues.", 79.25, 0.05, 99),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous setpoint', 77.59, 0.05, 100),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output from wind farm limited.', 74.85, 0.05, 101),
#  ('AURICON', 'AURICON_PNJ_U1', 'Generator transformer issue and unit protection.', 74.12, 0.05, 102),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramping up following delayed RTS due to unit trip', 74.11, 0.05, 103),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation after unit trip', 72.27, 0.05, 104),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up\n', 71.21, 0.05, 105),
#  ('AURICON', 'AURICON_PNJ_U1', 'High fogging system, PLC card failure', 68.71, 0.05, 106),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Stack emmission testing requirement and load swing\n', 67.72, 0.04, 107),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit unable to reach target due to ambient conditions.', 67.67, 0.04, 108),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to meet dispatch instruction.', 65.05, 0.04, 109),
#  ('AURICON', 'AURICON_PNJ_U1', 'Under generation - ambient conditions', 63.67, 0.04, 110),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp', 63.53, 0.04, 111),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 1 offline for HV maintenance', 62.2, 0.04, 112),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output reduced due to ambient conditions.', 60.05, 0.04, 113),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Contractor tuning requirement.', 56.64, 0.04, 114),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramp up following delayed RTS due to unit trip', 56.43, 0.04, 115),
#  ('AURICON', 'AURICON_PNJ_U1', 'Evaporative cooling inoperative due to demin water plant defect', 56.0, 0.04, 116),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delayed ramp-up to target', 53.18, 0.03, 117),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output limited due to ambient conditions', 45.13, 0.03, 118),
#  ('AURICON', 'AURICON_PNJ_U1', 'Three collector groups tripped offline due to a suspected cable fault', 44.6, 0.03, 119),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit derating', 44.59, 0.03, 120),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wind farm output limited', 44.1, 0.03, 121),
#  ('AURICON', 'AURICON_PNJ_U1', 'Maximum output limited due to ambient conditions', 43.12, 0.03, 122),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation on ramp up from outage', 43.0, 0.03, 123),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit output below dispatch target due to ambient conditions.', 42.51, 0.03, 124),
#  ('AURICON', 'AURICON_PNJ_U1', 'Local signal error', 42.1, 0.03, 125),
#  ('AURICON', 'AURICON_PNJ_U1', 'Limited maximum output', 41.51, 0.03, 126),
#  ('AURICON', 'AURICON_PNJ_U1', 'Under shoot dispatch target when ramping down', 41.01, 0.03, 127),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous dispatch', 40.15, 0.03, 128),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp down\n', 38.96, 0.03, 129),
#  ('AURICON', 'AURICON_PNJ_U1', 'Load swing testing', 38.11, 0.03, 130),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ1 max output reduced due to ambient conditions', 37.92, 0.02, 131),
#  ('AURICON', 'AURICON_PNJ_U1', 'Rotor temperature issue.', 37.6, 0.02, 132),
#  ('AURICON', 'AURICON_PNJ_U1', 'due to ambient condition', 36.35, 0.02, 133),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up from start up.', 36.32, 0.02, 134),
#  ('AURICON', 'AURICON_PNJ_U1', 'SCADA issue causing outage of 14 turbines', 36.1, 0.02, 135),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous dispatch.', 35.04, 0.02, 136),
#  ('AURICON', 'AURICON_PNJ_U1', 'Reserve capacity testing', 34.06, 0.02, 137),
#  ('AURICON', 'AURICON_PNJ_U1', 'Evaporative cooling ineffective due to ambient temperature.', 33.85, 0.02, 138),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 2 offline for HV maintenance', 31.1, 0.02, 139),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG1 and CG4 outage.', 30.0, 0.02, 140),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG1 outage.', 30.0, 0.02, 140),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output limited due to high ambient temperature', 27.45, 0.02, 142),
#  ('AURICON', 'AURICON_PNJ_U1', 'Communications outage', 26.1, 0.02, 143),
#  ('AURICON', 'AURICON_PNJ_U1', 'delayed ramp-up due to high fogging, evaporative cooler and water injection system', 24.48, 0.02, 144),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Stack emmission testing requirement\n', 23.71, 0.02, 145),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp', 23.62, 0.02, 146),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit had limited output.', 22.9, 0.02, 147),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit slow to ramp up.', 22.22, 0.01, 148),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ2 max output reduced due to ambient conditions.', 21.16, 0.01, 149),
#  ('AURICON', 'AURICON_PNJ_U1', 'delayed ramping due to ticking water valve that delayed the start of the power augmentation system', 20.97, 0.01, 150),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U1 failed to meet dispatch target due to ramping.', 19.21, 0.01, 151),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp rate due to power augmentation limitations', 18.71, 0.01, 152),
#  ('AURICON', 'AURICON_PNJ_U1', 'slow to ramp up ', 18.68, 0.01, 153),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up due to Blade Path Temperature control limit', 18.52, 0.01, 154),
#  ('AURICON', 'AURICON_PNJ_U1', 'Evaporative cooler pump issues\n', 18.44, 0.01, 155),
#  ('AURICON', 'AURICON_PNJ_U1', 'max output reduced due to ambient conditions.', 18.4, 0.01, 156),
#  ('AURICON', 'AURICON_PNJ_U1', 'Due to issues with the high fogging system', 17.41, 0.01, 157),
#  ('AURICON', 'AURICON_PNJ_U1', 'Outage of collector group 3 due to suspected cable fault trip', 15.1, 0.01, 158),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG1 outage', 15.0, 0.01, 159),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG4 outage.', 15.0, 0.01, 159),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group 1 de-energised to allow turbine repairs', 14.85, 0.01, 161),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group 5 outage caused by failure of RMU on turbine 44.', 14.85, 0.01, 161),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group outage', 14.85, 0.01, 161),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group unavailable due to a cable fault', 14.85, 0.01, 161),
#  ('AURICON', 'AURICON_PNJ_U1', 'Investigate and conduct reports on a turbine\n', 14.85, 0.01, 161),
#  ('AURICON', 'AURICON_PNJ_U1', 'turbine fault', 14.85, 0.01, 161),
#  ('AURICON', 'AURICON_PNJ_U1', 'Inlet temperature issues.', 14.07, 0.01, 167),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp for capacity testing', 13.77, 0.01, 168),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit unable to reach tartget due to ambient conditions', 13.65, 0.01, 169),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp to full capacity during capacity testing', 13.61, 0.01, 170),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramping limited on return to service', 13.47, 0.01, 171),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up.', 13.24, 0.01, 172),
#  ('AURICON', 'AURICON_PNJ_U1', 'Forced Outage', 11.35, 0.01, 173),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U2 max output reduced due to ambient conditions.', 10.3, 0.01, 174),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up.', 9.2, 0.01, 175),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit output below dispatch target due to ambient', 8.87, 0.01, 176),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit derating', 7.06, 0.0, 177),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp. Output limited due to ambient conditions.', 6.02, 0.0, 178),
#  ('AURICON', 'AURICON_PNJ_U1', 'Limited output due to ambient conditions', 5.82, 0.0, 179),
#  ('AURICON', 'AURICON_PNJ_U1', 'Reduced generation capability', 1.0, 0.0, 180),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84, 1),
#  ('GW', 'BW1_GREENWATERS_G2', 'FO', 833.6, 0.55, 2),
#  ('GW', 'BW1_GREENWATERS_G2', 'FO due to unit trip', 473.2, 0.31, 3),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit failed to start', 353.6, 0.23, 4),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit tripped', 348.4, 0.23, 5),
#  ('GW', 'BW1_GREENWATERS_G2', 'Gas Regulation issue', 342.0, 0.22, 6),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start\n', 213.2, 0.14, 7),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start triggering protection which affected Kemerton_GT11\n', 213.2, 0.14, 7),
#  ('GW', 'BW1_GREENWATERS_G2', 'Forced outage', 170.0, 0.11, 9),
#  ('GW', 'BW1_GREENWATERS_G2', 'Combustion chamber failed to fire.  Protection Shutdown.', 156.0, 0.1, 10),
#  ('GW', 'BW1_GREENWATERS_G2', 'Failed to start', 156.0, 0.1, 10),
#  ('GW', 'BW1_GREENWATERS_G2', 'No crane available Furnace 1 & 2. For further information contact Simcoa Furnace Control on 9780 6670', 123.9, 0.08, 12),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit 11 trip on gas detector failure', 103.0, 0.07, 13),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start triggering protection which affected Kemerton_GT11', 98.8, 0.06, 14),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational issue on start up', 98.8, 0.06, 14),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 unplanned outage', 88.2, 0.06, 16),
#  ('GW', 'BW1_GREENWATERS_G2', 'Intertrip from Western Power caused ME breaker 801.1 to open.  Intertrip as a result of a lightning storm in the area.  To be converted to a Consequential Outage.', 82.0, 0.05, 17),
#  ('GW', 'BW1_GREENWATERS_G2', 'forced outage due to western power ENAR309085', 82.0, 0.05, 17),
#  ('GW', 'BW1_GREENWATERS_G2', 'Ladle car derailment', 58.0, 0.04, 19),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil leak on Ph1', 49.0, 0.03, 20),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit trip on start', 46.8, 0.03, 21),
#  ('GW', 'BW1_GREENWATERS_G2', 'Baghouse Fans electrical trip', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'CV009 issues', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Chain curtain drive fault, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Chain curtain drive fault, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 - Server communication fault.  For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic hose failure', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Mechanical failure experienced on one of the main baghouse fans. Furnace 1&2 affected. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'No batching, Furnace 1 and 2. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Remove isolation plates on fan 12. Plant affected, Furnace 1 and 2. \n\nFor further information contact Simcoa Furnace Control on 9780 6670.', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water lines. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', 'Western Power Trip', 42.0, 0.03, 22),
#  ('GW', 'BW1_GREENWATERS_G2', ' Gt2 Fire panel fault', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fire Protection Fault', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 Fire protection instrument fault', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 Main Step Transformer temperature transducer lost signal making the TX unavailable.', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 Starter diesel failure to start.', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 fire protection panel instrument fault ', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 logic issue', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 went unavailable due to Fire System fault again, John from AEMO rang me at 1402 on Saturday 03 December.', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 went unavailable due to Fire System fault.', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 Caterpillar starter had issues, required a rebuild.', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 fire Panel fault', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 unable to synchronize to grid ', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 unavailable due to fire protection fault', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'fire protection fault', 41.0, 0.03, 33),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 outage', 38.5, 0.03, 47),
#  ('GW', 'BW1_GREENWATERS_G2', 'MCC Isolating Switch Fault', 38.5, 0.03, 47),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 tap hole breakout', 37.0, 0.02, 49),
#  ('GW', 'BW1_GREENWATERS_G2', 'Curtailment shutdown', 35.0, 0.02, 50),
#  ('GW', 'BW1_GREENWATERS_G2', 'Spring pack leak', 28.0, 0.02, 51),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start', 26.0, 0.02, 52),
#  ('GW', 'BW1_GREENWATERS_G2', 'Box overflowed, burnt tracks', 24.0, 0.02, 53),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic oil leak Phase 1 Contact Pad Lines', 23.8, 0.02, 54),
#  ('GW', 'BW1_GREENWATERS_G2', '11MVAr protection (breaker change out), Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Blown fume duct to ph1 electrode cooling', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Blown hydraulic hose, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Broken electrode. Kibble changeout. Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Casting crane failure. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Chain curtain drive fault', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Emergency generator caused hydraulic fault and demin water plant trip', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Flow meter problem on Line 35', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fu1 Chain curtain fallen off.  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fume duct issue', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 Outage', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 Phase 2 oil leak repair', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 water leak ? Transformer line 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 OOS', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 broken electrode phase 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2. Dango tripped with stoking arm in the furnace. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace off due to water leak on contact pad line - Furnace 2', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace repairs', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace1, Taphole repack.  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic leak', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic oil leak Phase 2 contact clamp', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Ladle car derailed, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Launder failure and rebuild. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'MCC fault', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'No water flow line 37 contact pad phase 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil Leak on Phase 2 .  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil leak', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil leak on ph1 furnace 1.  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repair fuel oil lines', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repair major water leak from pressure ring', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repair to floor plate stoking floor, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repairs to chain curtain', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Replace fume duct onto feeder 203, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Taphole blow and repack, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Taphole maintenance', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Taphole repair, Furnace1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Tapping fan MCC fault', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water leak Ph2 Fu1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water leak on hood', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water leak on phase 1 pressure ring. For further information contact Simcoa Furnace Control on 9780 6670 ', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'high current, incoming breaker faul', 21.0, 0.01, 55),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 - Taphole blow and repack ', 18.5, 0.01, 96),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1, Large Flame and repack. For further information contact Simcoa Furnace Control on 9780 6670', 17.0, 0.01, 97),
#  ('GW', 'BW1_GREENWATERS_G2', 'Start up curve, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 17.0, 0.01, 97),
#  ('GW', 'BW1_GREENWATERS_G2', 'Derailed box cart', 16.0, 0.01, 99),
#  ('GW', 'BW1_GREENWATERS_G2', '11MVar cap bank fault', 14.0, 0.01, 100),
#  ('GW', 'BW1_GREENWATERS_G2', '11MVar cap bank fault ', 14.0, 0.01, 100),
#  ('GW', 'BW1_GREENWATERS_G2', 'Launder failure Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 11.3, 0.01, 102),
#  ('GW', 'BW1_GREENWATERS_G2', 'Shutdown for baghouse fans blanks.  For further information contact Simcoa Furnace Control on 9780 6670', 11.0, 0.01, 103),
#  ('GW', 'BW1_GREENWATERS_G2', 'Startup after shut for oil leak', 11.0, 0.01, 103),
#  ('GW', 'BW1_GREENWATERS_G2', 'Delay energising', 10.0, 0.01, 105),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fan 13 off line due to maintenance work. For further information contact Simcoa Furnace Control on 9780 6670', 6.0, 0.0, 106),
#  ('GW', 'BW1_GREENWATERS_G2', 'ladle car derailment', 5.0, 0.0, 107),
#  ('GW', 'BW1_GREENWATERS_G2', 'No crane available Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 2.1, 0.0, 108),
#  ('GW', 'BW1_GREENWATERS_G2', 'Maintenance Shutdown - Total power used 0MW as Furnace 1 is still shutdown', 0.0, 0.0, 109),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72, 1),
#  ('MELK', 'MELK_G7', 'Unit trip - loss of ignition at low load', 972.18, 0.64, 2),
#  ('MELK', 'MELK_G7', 'Boiler inspection', 422.22, 0.28, 3),
#  ('MELK', 'MELK_G7', 'Boiler Repairs', 422.0, 0.28, 4),
#  ('MELK', 'MELK_G7', 'Unit MFT/MTR', 422.0, 0.28, 4),
#  ('MELK', 'MELK_G7', 'Delayed RTS', 416.9, 0.27, 6),
#  ('MELK', 'MELK_G7', 'Delayed Unit RTS.', 411.8, 0.27, 7),
#  ('MELK', 'MELK_G7', 'Governor Control Issues.', 411.8, 0.27, 7),
#  ('MELK', 'MELK_G7', 'Unit MTR.', 411.8, 0.27, 7),
#  ('MELK', 'MELK_G7', 'Loss off fire to the boiler resulting in pressure drop', 347.26, 0.23, 10),
#  ('MELK', 'MELK_G7', 'Delay in RTS from planned outage', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Forced full outage due to Air Compressor issues', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Full forced outage due to boiler feed pump trip', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Full forced outage due to unit trip.', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Full forced outage for RAH repairs', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Rotary air heater wash', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Unit trip due to hydraulic fault', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Unit tripped - LP heater level', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'forced outage due to unit trip', 343.24, 0.23, 11),
#  ('MELK', 'MELK_G7', 'Temperature related issues on ramp up', 339.69, 0.22, 20),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to precip fault', 320.0, 0.21, 21),
#  ('MELK', 'MELK_G7', 'Partial forced outage during turbine valve testing', 314.28, 0.21, 22),
#  ('MELK', 'MELK_G7', 'Pro-rata forced outage: Unit trip during turbine valve testing', 312.0, 0.2, 23),
#  ('MELK', 'MELK_G7', 'Pro-rata forced outage delay in return to service', 297.47, 0.2, 24),
#  ('MELK', 'MELK_G7', 'Pro rata outage due to air compressor issues', 297.47, 0.2, 25),
#  ('MELK', 'MELK_G7', 'Full forced outage (pro-rata) due to boiler feed pump trip', 295.62, 0.19, 26),
#  ('MELK', 'MELK_G7', 'Unit run back due to thermocouple fault.', 287.58, 0.19, 27),
#  ('MELK', 'MELK_G7', 'Boiler Tube Leak Repairs', 266.0, 0.17, 28),
#  ('MELK', 'MELK_G7', 'High silica restriction', 254.6, 0.17, 29),
#  ('MELK', 'MELK_G7', 'MFT / MTR', 227.0, 0.15, 30),
#  ('MELK', 'MELK_G7', 'Unit unavailable for RTS.', 227.0, 0.15, 30),
#  ('MELK', 'MELK_G7', 'Unit unavailable for dispatch.', 227.0, 0.15, 30),
#  ('MELK', 'MELK_G7', 'Retirement pending deregistration.', 220.0, 0.14, 33),
#  ('MELK', 'MELK_G7', 'Unit MFT/MTR.', 215.0, 0.14, 34),
#  ('MELK', 'MELK_G7', 'Delayed Return To service', 211.11, 0.14, 35),
#  ('MELK', 'MELK_G7', 'Delayed Synchronisation.', 211.0, 0.14, 36),
#  ('MELK', 'MELK_G7', 'RTS Delayed', 211.0, 0.14, 36),
#  ('MELK', 'MELK_G7', 'Unit MTR', 211.0, 0.14, 36),
#  ('MELK', 'MELK_G7', 'Boiler drain line damage', 208.98, 0.14, 39),
#  ('MELK', 'MELK_G7', 'Delayed Unit RTS', 208.98, 0.14, 39),
#  ('MELK', 'MELK_G7', 'Delays in unit return to service post major outage', 208.98, 0.14, 39),
#  ('MELK', 'MELK_G7', 'Low control oil pressure trip', 208.98, 0.14, 39),
#  ('MELK', 'MELK_G7', 'Unit trip due to hydraulic fault. Pro-rata forced outage', 206.0, 0.14, 43),
#  ('MELK', 'MELK_G7', 'Boiler Maintenance', 205.9, 0.14, 44),
#  ('MELK', 'MELK_G7', 'Master Fuel Trip, loss of fuel to feeder', 205.9, 0.14, 44),
#  ('MELK', 'MELK_G7', 'Unit Trip', 205.9, 0.14, 44),
#  ('MELK', 'MELK_G7', 'Unit delay RTS', 205.9, 0.14, 44),
#  ('MELK', 'MELK_G7', 'Hardwire trip fault', 200.0, 0.13, 48),
#  ('MELK', 'MELK_G7', 'Master fuel trip', 196.63, 0.13, 49),
#  ('MELK', 'MELK_G7', 'Load limitation', 193.0, 0.13, 50),
#  ('MELK', 'MELK_G7', 'Partial forced outage after unit runback caused by CW Pump trip', 190.0, 0.12, 51),
#  ('MELK', 'MELK_G7', 'Forced partial outage due to failure of CW pump.', 187.24, 0.12, 52),
#  ('MELK', 'MELK_G7', 'ID fan bearing failure - output reduced to 160MW', 183.24, 0.12, 53),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to CW pump trip.', 183.24, 0.12, 53),
#  ('MELK', 'MELK_G7', 'Forced outage: Unit trip during turbine valve testing', 180.0, 0.12, 55),
#  ('MELK', 'MELK_G7', 'condenser level trip', 175.08, 0.11, 56),
#  ('MELK', 'MELK_G7', 'Main Fuel Trip due to wet coal', 173.82, 0.11, 57),
#  ('MELK', 'MELK_G7', 'Partial forced outage. 3 mill operation', 171.19, 0.11, 58),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to CW pump trip', 163.24, 0.11, 59),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to delay in RTS', 160.0, 0.11, 60),
#  ('MELK', 'MELK_G7', 'Over-speed trip fault', 159.13, 0.1, 61),
#  ('MELK', 'MELK_G7', 'Pro rata forced outage due to unit trip', 157.39, 0.1, 62),
#  ('MELK', 'MELK_G7', 'Unable to fire the boiler on coal.', 155.9, 0.1, 63),
#  ('MELK', 'MELK_G7', 'Partial forced outage - Unit load restricted to 270MW.', 146.48, 0.1, 64),
#  ('MELK', 'MELK_G7', 'Forced partial outage (pro-rata) due to failure of CW pump.', 145.33, 0.1, 65),
#  ('MELK', 'MELK_G7', '11 KV supply Protection Activated', 145.0, 0.1, 66),
#  ('MELK', 'MELK_G7', 'HP Cylinder metal stress', 140.66, 0.09, 67),
#  ('MELK', 'MELK_G7', 'ID fan bearing failure - output reduced to 160MW (pro-rata)', 134.2, 0.09, 68),
#  ('MELK', 'MELK_G7', 'LP Differential Expansion issue', 133.14, 0.09, 69),
#  ('MELK', 'MELK_G7', 'Electrical fault causing turbine trip. Delayed synchronisation. Gate Closure Violation.', 132.5, 0.09, 70),
#  ('MELK', 'MELK_G7', 'Delay during synchronization', 130.06, 0.09, 71),
#  ('MELK', 'MELK_G7', 'ID fan control limitation', 126.11, 0.08, 72),
#  ('MELK', 'MELK_G7', 'Load reduction', 121.0, 0.08, 73),
#  ('MELK', 'MELK_G7', 'Load Limitation', 120.0, 0.08, 74),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage. 3 mill operation', 119.24, 0.08, 75),
#  ('MELK', 'MELK_G7', 'Boiler feed pump failure', 115.9, 0.08, 76),
#  ('MELK', 'MELK_G7', 'Boiler inspection ', 115.0, 0.08, 77),
#  ('MELK', 'MELK_G7', 'Under Voltage Relay Trip', 109.5, 0.07, 78),
#  ('MELK', 'MELK_G7', 'Partial load restriction', 108.0, 0.07, 79),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage due to CW pump trip.', 103.84, 0.07, 80),
#  ('MELK', 'MELK_G7', 'Turbine limitation', 102.46, 0.07, 81),
#  ('MELK', 'MELK_G7', 'Mill trips took unit offline', 102.22, 0.07, 82),
#  ('MELK', 'MELK_G7', 'Feedwater restriction.', 100.0, 0.07, 83),
#  ('MELK', 'MELK_G7', 'Unavailability of plant', 100.0, 0.07, 83),
#  ('MELK', 'MELK_G7', 'Loss of vacuum trip', 99.77, 0.07, 85),
#  ('MELK', 'MELK_G7', 'Mill trip', 98.89, 0.06, 86),
#  ('MELK', 'MELK_G7', 'Pro-rata Unit run back due to thermocouple fault.', 97.9, 0.06, 87),
#  ('MELK', 'MELK_G7', 'Condenser and cooling tower performance', 95.0, 0.06, 88),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to delay in RTS (pro-rata)', 90.66, 0.06, 89),
#  ('MELK', 'MELK_G7', 'Unit trip', 85.9, 0.06, 90),
#  ('MELK', 'MELK_G7', 'Turbine LH ESV opening fault', 81.0, 0.05, 91),
#  ('MELK', 'MELK_G7', 'Full forced outage for RAH repairs (pro-rata)', 80.0, 0.05, 92),
#  ('MELK', 'MELK_G7', 'ID fan capacity', 80.0, 0.05, 92),
#  ('MELK', 'MELK_G7', 'FD fan control limitation', 78.98, 0.05, 94),
#  ('MELK', 'MELK_G7', 'Low furnace pressure due to loss of fuel supply', 78.85, 0.05, 95),
#  ('MELK', 'MELK_G7', 'Loss of temperature in the boiler', 77.87, 0.05, 96),
#  ('MELK', 'MELK_G7', 'ID fan bearing failure - Pro-rata load reduction to 160MW', 74.8, 0.05, 97),
#  ('MELK', 'MELK_G7', 'PA fan capacity', 69.0, 0.05, 98),
#  ('MELK', 'MELK_G7', 'Issue with feeder', 68.99, 0.05, 99),
#  ('MELK', 'MELK_G7', 'Wet Coal Issues', 65.43, 0.04, 100),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to mill issue', 63.24, 0.04, 101),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage after unit runback caused by CW Pump trip', 60.17, 0.04, 102),
#  ('MELK', 'MELK_G7', 'Cooling Tower Fans tripped.', 60.0, 0.04, 103),
#  ('MELK', 'MELK_G7', 'Pro-rata forced outage after unit trip', 57.2, 0.04, 104),
#  ('MELK', 'MELK_G7', 'Brush Gear repairs', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Electrical fault resulting in turbine trip', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Governor Control Fault', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'M7 CW temperature high', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Over speed bolt test unsuccessful  ', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Steam to metal temperature mismatch across turbine', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Synchronisation delay due to temperature related issues', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Technical support required to synchronise due to bearing vibrations', 55.0, 0.04, 105),
#  ('MELK', 'MELK_G7', 'Partial forced outage (pro-rata) due to CW pump trip', 54.4, 0.04, 113),
#  ('MELK', 'MELK_G7', 'Partial forced outage (pro-rata) due to mill issue', 53.5, 0.04, 114),
#  ('MELK', 'MELK_G7', 'Runback due to loss of fuel supply', 51.98, 0.03, 115),
#  ('MELK', 'MELK_G7', 'Delay to unit synchronization', 48.23, 0.03, 116),
#  ('MELK', 'MELK_G7', 'Turbine governor valve fault', 47.11, 0.03, 117),
#  ('MELK', 'MELK_G7', 'Centre CW pump outage', 47.0, 0.03, 118),
#  ('MELK', 'MELK_G7', 'Partial forced outage (pro-rata) due to boiler feed pump trip', 46.11, 0.03, 119),
#  ('MELK', 'MELK_G7', 'Pro-rata full forced outage due to unit trip.', 45.78, 0.03, 120),
#  ('MELK', 'MELK_G7', 'Erratic governor control system  ', 45.14, 0.03, 121),
#  ('MELK', 'MELK_G7', 'M7 Cooling Tower Fans tripped.', 45.0, 0.03, 122),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to ESP pass out of service', 43.24, 0.03, 123),
#  ('MELK', 'MELK_G7', 'FW limitation', 43.0, 0.03, 124),
#  ('MELK', 'MELK_G7', 'Turbine temperature and vibration issues during ramp up', 42.06, 0.03, 125),
#  ('MELK', 'MELK_G7', 'Unit ramped up slower than scheduled due to temperature differentials', 41.23, 0.03, 126),
#  ('MELK', 'MELK_G7', 'Issue with Variable Speed Drive on Pulveriser A/B', 40.1, 0.03, 127),
#  ('MELK', 'MELK_G7', 'M8 CW temperature high and poor vacuum', 40.0, 0.03, 128),
#  ('MELK', 'MELK_G7', 'RAH Blockage limiting load', 39.0, 0.03, 129),
#  ('MELK', 'MELK_G7', 'Partial pro-rata forced outage due to ESP pass out of service', 38.91, 0.03, 130),
#  ('MELK', 'MELK_G7', 'Reduced load ', 37.0, 0.02, 131),
#  ('MELK', 'MELK_G7', 'RAH high load', 31.11, 0.02, 132),
#  ('MELK', 'MELK_G7', 'Boiler combustion plant capacity', 30.0, 0.02, 133),
#  ('MELK', 'MELK_G7', 'Issue with oil guns', 29.44, 0.02, 134),
#  ('MELK', 'MELK_G7', 'Drum level indication and control fault', 27.0, 0.02, 135),
#  ('MELK', 'MELK_G7', 'Forced partial outage due to mill trip', 27.0, 0.02, 135),
#  ('MELK', 'MELK_G7', 'Boiler issue', 25.6, 0.02, 137),
#  ('MELK', 'MELK_G7', 'Pro rata partial forced outage after unit runback caused by CW Pump trip', 25.33, 0.02, 138),
#  ('MELK', 'MELK_G7', 'Issue with the feeder', 25.02, 0.02, 139),
#  ('MELK', 'MELK_G7', 'Verbal DI to increase load. Unit ramped up slower than submitted ramp rate due to temperature differentials', 24.18, 0.02, 140),
#  ('MELK', 'MELK_G7', 'Load restriction', 22.0, 0.01, 141),
#  ('MELK', 'MELK_G7', 'Partial pro-rata forced outage due to precip fault', 21.67, 0.01, 142),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage - Unit load restricted to 270MW from 18:52.', 19.53, 0.01, 143),
#  ('MELK', 'MELK_G7', 'Pro-rata Partial forced outage. 3 mill operation', 18.81, 0.01, 144),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to PF leak on mill. Unit reduced to three mill operation.', 18.24, 0.01, 145),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to mill failure. Reduced to three mill operation.', 18.24, 0.01, 145),
#  ('MELK', 'MELK_G7', 'loss of a cooling tower fan', 16.93, 0.01, 147),
#  ('MELK', 'MELK_G7', 'operator was delayed in initiating ramp up', 15.08, 0.01, 148),
#  ('MELK', 'MELK_G7', 'High differential pressure in the baghouse', 15.0, 0.01, 149),
#  ('MELK', 'MELK_G7', 'Boiler capacity', 14.0, 0.01, 150),
#  ('MELK', 'MELK_G7', 'Additional DI instructed within interval when unit was already ramping. Unable to comply.', 13.9, 0.01, 151),
#  ('MELK', 'MELK_G7', 'issue with the baghouse', 13.78, 0.01, 152),
#  ('MELK', 'MELK_G7', 'Mill A and Mill C starting faults', 11.9, 0.01, 153),
#  ('MELK', 'MELK_G7', 'Baghouse Issues', 10.0, 0.01, 154),
#  ('MELK', 'MELK_G7', 'Loss of a cooling tower fan', 10.0, 0.01, 154),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage due to mill failure. Reduced to three mill operation for 15 minutes.', 9.12, 0.01, 156),
#  ('MELK', 'MELK_G7', 'Turbine vibrations', 8.98, 0.01, 157),
#  ('MELK', 'MELK_G7', 'West Boiler feed pump Outage', 8.0, 0.01, 158),
#  ('MELK', 'MELK_G7', 'operator was delayed in initiating ramp up ', 7.9, 0.01, 159),
#  ('MELK', 'MELK_G7', 'Loss of a mill', 7.48, 0.0, 160),
#  ('MELK', 'MELK_G7', 'Boiler feed pump, condenser and cooling tower performance', 7.0, 0.0, 161),
#  ('MELK', 'MELK_G7', 'Coal feeder swap', 6.82, 0.0, 162),
#  ('MELK', 'MELK_G7', 'Coal issue', 6.74, 0.0, 163),
#  ('MELK', 'MELK_G7', 'Mill Issue', 6.12, 0.0, 164),
#  ('MELK', 'MELK_G7', 'Baghouse issue resulting in restricted load', 5.0, 0.0, 165),
#  ('MELK', 'MELK_G7', 'Baghouse issue resulting in restricted load\n', 5.0, 0.0, 165),
#  ('MELK', 'MELK_G7', 'Rotary Air Heater seals', 4.72, 0.0, 167),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage due to PF leak on mill. Unit reduced to three mill operation.', 4.26, 0.0, 168),
#  ('MELK', 'MELK_G7', 'Boiler feedpump capacity', 4.0, 0.0, 169),
#  ('MELK', 'MELK_G7', 'North Boiler feed pump oil leak', 4.0, 0.0, 169),
#  ('MELK', 'MELK_G7', 'Turbine control limitations', 4.0, 0.0, 169),
#  ('MELK', 'MELK_G7', 'Turbine limitations', 4.0, 0.0, 169)]

# %% [markdown]
# **Insight**:
#
# An in-depth analysis of forced outage data across 2016–2017 reveals that the top three contributors to energy loss—**GW**, **AURICON**, and **MELK**—each face distinct root causes behind their most severe disruptions:
#
# - **GW (BW1_GREENWATERS_G2)** experienced the highest energy loss due to *real-time operational issues*, resulting in over **28,600 MWh lost**—accounting for nearly **19%** of all forced outage-related energy loss. This highlights significant gaps in operational readiness and system stability.
#
# - **AURICON (AURICON_PNJ_U1)** saw its largest impact from a *full unit trip*, contributing **6,034 MWh** in lost energy, or nearly **4%** of the total. This suggests critical *equipment-level vulnerabilities* affecting supply continuity.
#
# - **MELK (MELK_G7)** reported **1,100 MWh** in losses due to *safety-related shutdowns*. Although lower in volume, the nature of the issue raises concerns around *risk management* and *regulatory compliance*.
